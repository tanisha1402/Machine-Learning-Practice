# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/1.Google_Collab_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# System Specifications

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi its
# bogomips	: 4399.99
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13286772 kB
# MemFree:         9550824 kB
# MemAvailable:   12289408 kB
# Buffers:          109968 kB
# Cached:          2828840 kB
# SwapCached:            0 kB
# Active:           425716 kB
# Inactive:        3084396 kB
# Active(anon):       1388 kB
# Inactive(anon):   571884 kB
# Active(file):     424328 kB
# Inactive(file):  2512512 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:                48 kB
# Writeback:             0 kB
# AnonPages:        571352 kB
# Mapped:           410056 kB
# Shmem:              1960 kB
# KReclaimable:      85592 kB
# Slab:             121920 kB
# SReclaimable:      85592 kB
# SUnreclaim:        36328 kB
# KernelStack:        5072 kB
# PageTables:         8448 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6643384 kB
# Committed_AS:    2642292 kB
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Data
X = np.array([[1], [2], [3], [4], [5]])  # hours studied
y = np.array([2, 4, 5, 4, 5])            # marks

# Create model
model = LinearRegression()
model.fit(X, y)

# Predict
predictions = model.predict(X)

# Print slope and intercept
print("Slope (w):", model.coef_[0])
print("Intercept (b):", model.intercept_)

# Plot
plt.scatter(X, y, color='red')   # actual data
plt.plot(X, predictions, color='blue')  # best fit line
plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.show()
# Out:
# Slope (w): 0.6
# Intercept (b): 2.2

# %% [markdown]
# Installing Libraries

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('BostonHousing.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV  CAT. MEDV
# 0   4.98  24.0          0
# 1   9.14  21.6          0
# 2   4.03  34.7          1
# 3   2.94  33.4          1
# 4   5.33  36.2          1

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
# !ls
# Out:
# BostonHousing.csv  sample_data
