# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/Loops_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # for loop

# %%
for i in range(5):
  laptop_price=int(input("Enter the price of the laptop: "))
# Out:
# Enter the price of the laptop: 10
# Enter the price of the laptop: 9
# Enter the price of the laptop: 99
# Enter the price of the laptop: 89
# Enter the price of the laptop: 78

# %%
numbers = [1,2,3,4,5]
for i in numbers:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # while loop

# %%
i = 0
while(i<5):
  print(i)
  i +=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# in python we don't have do while loop
do:
print("it is within the limit")
while(i<10):
  i = int(input("Enter the number: "))
# Out:
#   File "/tmp/ipython-input-596530587.py", line 2
#     do:
#        ^
# SyntaxError: invalid syntax
