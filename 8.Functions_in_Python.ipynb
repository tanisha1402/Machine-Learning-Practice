# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/8.Functions_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Function
#  function is a block of code that can be reused in a program
#
# Factorial of a number is the product of all the positive numbers less than or equal to that number

# %%
number = int(input("Enter a number: "))
factorial = 1
if number==0:
  print("The factorial of 0 is 1")
else:
  for i in range (1,number+1):
    factorial = factorial * i
  print("The factorial of", number, "is", factorial)

# %% [markdown]
# Factorial Function

# %%
def fact(num):
  factorial = 1
  if(num==0):
    return factorial
  else:
     for i in range (1,num+1):
      factorial = factorial * i
  return factorial

# %%
print(fact(5))
# Out:
# 120

# %%
print(fact(10))
# Out:
# 3628800
