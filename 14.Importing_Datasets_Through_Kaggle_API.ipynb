# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/14.Importing_Datasets_Through_Kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# API - Application Programming Interface

# %%
# installing the Kaggle library
# !pip install kaggle

# %% [markdown]
# Upload your Kaggle.json file

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Importing the Earthquake Dataset

# %%
# API to fetch the dataset from Kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
#  99% 2.24G/2.27G [00:20<00:00, 245MB/s]
# 100% 2.27G/2.27G [00:20<00:00, 118MB/s]

# %%
# unzip the dataset
# !unzip LANL-Earthquake-Prediction.zip -d lanl_earthquake
# Out:
# Archive:  LANL-Earthquake-Prediction.zip
#   inflating: lanl_earthquake/sample_submission.csv
#   inflating: lanl_earthquake/test/seg_00030f.csv
#   inflating: lanl_earthquake/test/seg_0012b5.csv
#   inflating: lanl_earthquake/test/seg_00184e.csv
#   inflating: lanl_earthquake/test/seg_003339.csv
#   inflating: lanl_earthquake/test/seg_0042cc.csv
#   inflating: lanl_earthquake/test/seg_004314.csv
#   inflating: lanl_earthquake/test/seg_004cd2.csv
#   inflating: lanl_earthquake/test/seg_004ee5.csv
#   inflating: lanl_earthquake/test/seg_004f1f.csv
#   inflating: lanl_earthquake/test/seg_00648a.csv
#   inflating: lanl_earthquake/test/seg_006e4a.csv
#   inflating: lanl_earthquake/test/seg_007a37.csv
#   inflating: lanl_earthquake/test/seg_00a37e.csv
#   inflating: lanl_earthquake/test/seg_00be11.csv
#   inflating: lanl_earthquake/test/seg_00c35b.csv
#   inflating: lanl_earthquake/test/seg_00cc91.csv
#   inflating: lanl_earthquake/test/seg_00e5f7.csv
# ...

# %%
# extracting the compessed Dataset
from zipfile import ZipFile

with ZipFile('/content/LANL-Earthquake-Prediction.zip', 'r') as zip_ref:
    zip_ref.extract('train.csv', '/content/lanl_earthquake')
    print('train.csv extracted!')
# Out:
# train.csv extracted!
