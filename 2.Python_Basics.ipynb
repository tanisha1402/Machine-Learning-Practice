# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/2.Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Programming Languages Used For ML
#
# 1. Python
# 2. R

# %% [markdown]
# #**Print Function**

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
print("Machine Learning"+" Using Python")
# Out:
# Machine Learning Using Python

# %%
print(8)
# Out:
# 8

# %%
print(8+3)
# Out:
# 11

# %% [markdown]
# #**Basic Data Types**
# 1. int
# 2. float
# 3. str

# %%
type(8)
# Out:
# int

# %%
type(4.4)
# Out:
# float

# %%
type("ML")
# Out:
# str

# %% [markdown]
# # **Constants & Variables**
#  Constants can't be changed but Variables can

# %%
variables_cannot_have_spaces= "Variable"

# %%
print(variables_cannot_have_spaces)
# Out:
# Variable

# %%
var1,var2,var3="Var1_1","Var2_2","Var3_3"

# %%
print(var1,var2,var3)
# Out:
# Var1_1 Var2_2 Var3_3

# %%
x=y=z=100

# %% [markdown]
# # **Input Function**

# %%
n1 = input("Enter the number : ")
n2 = input("Enter the number : ")
print(n1,n2)
sum = n1+n2
print(sum)
# Out:
# Enter the number : 23
# Enter the number : 23
# 23 23
# 2323

# %%
n1 = int(input("Enter the number : "))
n2 = int(input("Enter the number : "))
print(n1,n2)
sum = n1+n2
print(sum)
# Out:
# Enter the number : 23
# Enter the number : 23
# 23 23
# 46

# %% [markdown]
# # **Changing the data types**

# %%
n1= 3
print(n1)
# Out:
# 3

# %%
print(float(n1))
# Out:
# 3.0
