# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/Projects/Text_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libarary

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Dataset Prepare

# %%
data = {
    'text':['I Love NLP','I Love this scenary','This movie is hated','Best Movie ever','Worst movie ever'],
    'label':['Positive','Positive','Negative','Positive','Negative']
}

# %%
df= pd.DataFrame(data)

# %%
df.head()
# Out:
#                   text     label
# 0           I Love NLP  Positive
# 1  I Love this scenary  Positive
# 2  This movie is hated  Negative
# 3      Best Movie ever  Positive
# 4     Worst movie ever  Negative

# %% [markdown]
# Split Dataset

# %%
x_train , x_test , y_train , y_test = train_test_split(df['text'],df['label'],test_size=0.2,random_state=42)

# %% [markdown]
# Feature Extraction

# %%
vectorizer = TfidfVectorizer()
x_train_vectorized = vectorizer.fit_transform(x_train)
x_test_vectorized = vectorizer.transform(x_test)

# %%
model = MultinomialNB()
model.fit(x_train_vectorized,y_train)
# Out:
# MultinomialNB()

# %%
y_predict = model.predict(x_test_vectorized)

# %%
print(accuracy_score(y_test,y_predict))
# Out:
# 1.0

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#     Positive       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1

# %%
new_text = input('enter your sentence : ')
new_text_vec = vectorizer.transform([new_text])
prediction = model.predict(new_text_vec)
print(prediction)
# Out:
# enter your sentence : i love movies
# ['Positive']
