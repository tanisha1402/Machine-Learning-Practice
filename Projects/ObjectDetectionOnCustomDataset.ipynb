# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/Projects/ObjectDetectionOnCustomDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sXH3rwIaTQCElWQEImel")
project = rf.workspace("roboflow-universe-projects").project("construction-site-safety")
version = project.version(30)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 120.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Construction-Site-Safety-30 in yolov11:: 100%|██████████| 1446/1446 [00:00<00:00, 4213.19it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs=5 imgsz=640
# Out:
# ...
# Ultralytics 8.3.247 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task = detect mode = predict model = /content/runs/detect/train/weights/best.pt source = /content/Construction-Site-Safety-30/test/images save  = True
# Out:
# Ultralytics 8.3.247 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,587,027 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/82 /content/Construction-Site-Safety-30/test/images/-4405-_png_jpg.rf.937688313347dbcd3b24201dd7882906.jpg: 640x640 (no detections), 14.9ms
# image 2/82 /content/Construction-Site-Safety-30/test/images/000005_jpg.rf.c613c066b79795d219855aca269760e6.jpg: 448x640 (no detections), 69.8ms
# image 3/82 /content/Construction-Site-Safety-30/test/images/002551_jpg.rf.b09484b130c1587abfa8365c3d774bf1.jpg: 448x640 1 Person, 10.9ms
# image 4/82 /content/Construction-Site-Safety-30/test/images/003357_jpg.rf.9fb1f2cebc239b4276a81ce2cbf9e911.jpg: 480x640 (no detections), 74.9ms
# image 5/82 /content/Construction-Site-Safety-30/test/images/004063_jpg.rf.6ecc587c20a87ec176841aea39b8f5db.jpg: 448x640 2 Hardhats, 1 NO-Hardhat, 5 Persons, 10.6ms
# ...
