# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/Projects/Hand_Gesture_Recognation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 89.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 134.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sXH3rwIaTQCElWQEImel")
project = rf.workspace("graduation-project-i4jtz").project("sign-language-lip2g")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Sign-language-5 in yolov11:: 100%|██████████| 3104/3104 [00:00<00:00, 6431.33it/s]

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# Train Model

# %%
# !yolo task = detect mode = train model= yolo11n.pt data = {dataset.location}/data.yaml epochs = 5 imgsz = 640
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task = detect mode =  predict model = '/content/runs/detect/train3/weights/best.pt' source = '/content/Sign-language-5/test/images' conf = 0.5 save = True
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/35 /content/Sign-language-5/test/images/149_jpg.rf.97eec917f1d3a3461a6eb2363e79b77d.jpg: 640x640 1 thaa, 11.2ms
# image 2/35 /content/Sign-language-5/test/images/158_jpg.rf.60f9c211de947ed81da2aa948f347c4f.jpg: 640x640 1 thaa, 7.9ms
# image 3/35 /content/Sign-language-5/test/images/159_jpg.rf.54d13494b77345dd7d1467451e586c3b.jpg: 640x640 1 thaa, 7.9ms
# image 4/35 /content/Sign-language-5/test/images/15_jpg.rf.e6b6eec893ba695a6ccf9bb8d4e7c0f2.jpg: 640x640 1 thaa, 7.9ms
# image 5/35 /content/Sign-language-5/test/images/174_jpg.rf.d0051ef9bdac312e68fd4b69fdb6050a.jpg: 640x640 1 thaa, 7.9ms
# image 6/35 /content/Sign-language-5/test/images/175_jpg.rf.c5387f0f682eee3cdef3486845b7080f.jpg: 640x640 1 thaa, 7.9ms
# ...
