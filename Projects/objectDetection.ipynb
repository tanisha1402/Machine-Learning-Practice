# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/Projects/objectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolo11n.pt')

# %%
result= model('/content/img1.jpg',save=True)
# Out:
# image 1/1 /content/img1.jpg: 640x448 3 persons, 1 sports ball, 296.7ms
# Speed: 32.3ms preprocess, 296.7ms inference, 155.9ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to /content/runs/detect/predict3

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=672x1024>

# %%
from ultralytics import YOLO
model = YOLO('yolo11n.pt')
result_video = model.predict('/content/manPlayingFootball.mp4', save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/367) /content/manPlayingFootball.mp4: 352x640 8 persons, 1 car, 1 bench, 1 sports ball, 196.3ms
# video 1/1 (frame 2/367) /content/manPlayingFootball.mp4: 352x640 7 persons, 2 cars, 1 bench, 1 sports ball, 24.0ms
# video 1/1 (frame 3/367) /content/manPlayingFootball.mp4: 352x640 10 persons, 2 cars, 1 bench, 1 sports ball, 15.8ms
# ...
