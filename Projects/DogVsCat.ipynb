# %% [markdown]
# <a href="https://colab.research.google.com/github/tanisha1402/Machine-Learning-Practice/blob/main/Projects/DogVsCat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_data = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_data = ImageDataGenerator(rescale=1./255)

# %%
# !unzip "/content/drive/MyDrive/archive (1).zip" -d "/content/drive/MyDrive/Dataset"
# Out:
# Archive:  /content/drive/MyDrive/archive (1).zip
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_1.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_106.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_109.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_113.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_114.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_116.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_118.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_119.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_124.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_140.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_147.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_156.jpg
#   inflating: /content/drive/MyDrive/Dataset/test/cat_s/cat_158.jpg
# ...

# %%
train_set= train_data.flow_from_directory('/content/drive/MyDrive/Dataset/train',target_size=(64,64),batch_size=32,class_mode='binary')
# Out:
# Found 555 images belonging to 2 classes.

# %%
test_set= test_data.flow_from_directory('/content/drive/MyDrive/Dataset/test',target_size=(64,64),batch_size=32,class_mode='binary')
# Out:
# Found 138 images belonging to 2 classes.

# %%
cnn = tf.keras.models.Sequential()

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Dense Layer

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %%
cnn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
cnn.fit(x=train_set,validation_data=test_set,epochs=5)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 13s 474ms/step - accuracy: 0.5149 - loss: 0.7911 - val_accuracy: 0.5000 - val_loss: 0.6955
# Epoch 2/5
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.5193 - loss: 0.6915 - val_accuracy: 0.4928 - val_loss: 0.6919
# Epoch 3/5
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.5182 - loss: 0.6899 - val_accuracy: 0.5435 - val_loss: 0.6920
# Epoch 4/5
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 419ms/step - accuracy: 0.5916 - loss: 0.6746 - val_accuracy: 0.5435 - val_loss: 0.6837
# Epoch 5/5
# ...

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/Dataset/test/dogs/dog_194.jpg',target_size=(64,64))

# %%
test_image = image.img_to_array(test_image)

# %%
test_image = np.expand_dims(test_image,axis=0)

# %%
result = cnn.predict(test_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step

# %%
train_set.class_indices
if result[0][0] == 1 :
  prediction = 'dog'
else :
  prediction = 'cat'

# %%
print(prediction)
# Out:
# dog
